# %%
#!pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="DBuGtcWnfPWs3WpOmusT")
project = rf.workspace("ofyns").project("crime-detection-dupwb-g0zsc")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Crime-detection-1 to yolov8:: 100%|██████████| 96427/96427 [00:53<00:00, 1787.08it/s]
# Extracting Dataset Version Zip to Crime-detection-1 in yolov8:: 100%|██████████| 3224/3224 [00:01<00:00, 1981.16it/s]
